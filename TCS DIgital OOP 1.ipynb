# %% [markdown]
# Create a class College with below attributes:
#
# int - collegeID
#
# String - Name
#
# int - City
#
# double - Rating
#
# Create the _init_ method which takes all parameters in the above sequence.
# The method should set the value of attributes to parameter values inside the method.
#
# Create a class University with below attributes:
#
# String - universityName
#
# String - collegeCollection
#
# Create the _init_ method which takes all parameters in the above sequence.
# The method should set the value of attributes to parameter values inside the method.
#
# Implement two  methods - searchCollegeByName and countCollegeByRating in University class.
#
# searchCollegeByName
# Create a  method  searchCollegeByName in the   University class.This method will take Name as argument.The method will filter  Colleges based on Name attribute and create a new list of Colleges.The method will return the College  list and if no match found return NONE to main program.
#
# countCollegeByRating
# Create a  method  countCollegeByRating  in the  University class.This method will find the count of Colleges enrolled for each Rating from the  CollegeList of the  University class and returns a dictionary having the Rating and  CollegeCount (count of  Colleges) as key:value pair.
#
# These methods should be called from the main method.
#
# Instructions to write main section of the code:
#
# a. You would require to write the main section completely, hence please follow the below instructions for the same.
#
# b. You would require to write the main program which is inline to the sample input description section  mentioned below and to read the data in the same sequence.
#
# c. To create University and College objects , take the inputs in below sequence.
#
#   To create a List of n College objects read the value of n.
#
#   To create a List of n College objects read values for collegeID,Rating,City,Name,and create the College object and add to the List. Repeat this step n times.
#
# Create the University object by passing the List of College created in previous step.
#
# d. Read the value for the argument to be passed to the method searchCollegeByName.
#
# e. Call the method searchCollegeByName of the University object created in point  #c. by passing the argument read in point #d.
#
# f. Call the method countCollegeByRating of the University object created in point #c.
#
# g. Print the output of both methods as per given sample output.
#
# h. If there is NONE returned from any method print-No Data Found.
#
# Don't use any static text or formatting for printing the result. Just invoke the method and print the result.
#
# Sequence for specific object will follow same attribute sequence as mentioned in the question.You may refer to the sample Input/output for the display format.
#
# Sample 1 Input:
#
# 5
# 60
# 478
# 19
# izeoczo
# 67
# 356
# 73
# jbwdqvb
# 50
# 401
# 66
# unagyxg
# 77
# 666
# 66
# onhegev
# 59
# 429
# 50
# vpipbvu
# izeoczo
# Sample 1 Output:
#
# 60
# 478
# 19
# izeoczo
# 356 1
# 478 1
# 401 1
# 666 1
# 429 1

# %%
class College:
    def __init__(self,collegeID,name,city,rating):
        self.collegeID = collegeID
        self.name = name
        self.city=city
        self.rating=rating
        
class University:
    def __init__(self,universityName,collegeCollection):
        self.universityName = universityName
        self.collegeCollection = collegeCollection
        
    def searchCollegeByName(self,Name):
        clgList=[]
        flag=0
        for i in self.collegeCollection:
            if i.name==Name:
                flag=1
                clgList.append(i)
        if flag==1:
            return clgList
        else:
            return None
            
    def countCollegeByRating(self):
        #finding the different ratings
        output = dict()
        ratingsList=[]
        for college in self.collegeCollection:
            ratingsList.append(college.rating)
        ratingSet = set(ratingsList)
        new_ratingsList=[]
        new_ratingsList = list(ratingSet) #Unique ratings list
        for rating in new_ratingsList:
            count=0
            for college in self.collegeCollection:
                if college.rating==rating:
                    count=count+1
            output[rating]=count
        return output
if __name__=="__main__":
    n=int(input())
    l=[]
    for i in range(n):
        identity = int(input())
        rate = int(input())
        city = int(input())
        name = input()
        l.append(College(identity,rate,city,name))
    u1=University("RGPV",)
    u2=u1.searchCollegeByName(input())
    u3 = u1.countCollegeByRating()
    if u2==None:
        print("No Data Found")
    else:
        for i in u2:
            print(i.collegeID)
            print(i.rating)
            print(i.city)
            print(i.name)
        for j in u3:
            print(j,u3[j])
# Out:
# 5
# 60
# 478
# 19
# izeoczo
# 67
# 356
# 73
# jbwdqvb
# 50
# 401
# 66
# unagyxg
# 77
# 666
# 66
# onhegev
# 59
# 429
# 50
# vpipbvu
# izeoczo
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-1ae4cc148169> in <module>
#      49         l.append(College(identity,rate,city,name))
#      50     u1=University("RGPV",1)
# ---> 51     u2=u1.searchCollegeByName(input())
#      52     u3 = u1.countCollegeByRating()
#      53     if u2==None:
#
# <ipython-input-2-1ae4cc148169> in searchCollegeByName(self, Name)
#      14         clgList=[]
#      15         flag=0
# ---> 16         for i in self.collegeCollection:
#      17             if i.name==Name:
#      18                 flag=1
#
# TypeError: 'int' object is not iterable
