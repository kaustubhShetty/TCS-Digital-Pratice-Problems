# %% [markdown]
# Create a class Magazine with below attributes:
#
# String - Name
#
# String - Author
#
# double - Cost
#
# int - Viewers
#
# Create the __init__ method which takes all parameters in the above sequence.
# The method should set the value of attributes to parameter values inside the method.
#
# Create a class Publisher with below attributes:
#
# String - publishingHouse
#
# String - magazineCollection is of type dictionary with Magazine objects [ Publisher Name and  the respective Magazine object as key : value pair ]
#
#
#
# Create the __init__ method which takes all parameters in the above sequence.
# The method should set the value of attributes to parameter values inside the method.
#
# Implement two  methods - searchMagazineByAuthor and findMaximumMagazineByViewers in Publisher class.
#
# searchMagazineByAuthor
# Create a  method  searchMagazineByAuthor in the   Publisher class.This method will find the respective Magazine object based on the Author of the Magazine supplied as an argument from the dictionary of Magazine objects (in the Publisher class) and return a list of Magazine objects , whose Author  if matches with the given Author ,supplied as argument.If there is no Magazine  found with the given  Author  then return None .
#
# findMaximumMagazineByViewers
# Create a  method  findMaximumMagazineByViewers  in the  Publisher class. This method will return the Magazine having the maximum value for  Viewers of all the Magazines  in the Magazine dictionary of the Publisher class. If there is no  Magazine    found in the   Magazine dictionary or dictionary is empty then return NONE  to main program.
#
# These methods should be called from the main method.
#
# Instructions to write main section of the code:
#
# a. You would require to write the main section completely, hence please follow the below instructions for the same.
#
# b. You would require to write the main program which is inline to the sample input description section  mentioned below and to read the data in the same sequence.
#
# c. To create Publisher and Magazine objects , take the inputs in below sequence.
#
#   To create a Dictionary of n Magazine objects read the value of n.
#
#   To create a Dictionary of n Magazine objects read values for Author,Viewers,Cost,Name,and create the Magazine object and add to the Dictionary add Publisher Name as Key to dictionary.
#
# Publisher Name  of the first element to be added to the dictionary as 'A' and will be increased alphabatically for next elements to be added. Repeat this step n times.
#
# Create the Publisher object by passing the Dictionary of Magazine created in previous step.
#
# d. Read the value for the argument to be passed to the method searchMagazineByAuthor.
#
# e. Call the method searchMagazineByAuthor of the Publisher object created in point  #c. by passing the argument read in point #d.
#
# f. Call the method findMaximumMagazineByViewers of the Publisher object created in point #c.
#
# g. Print the output of both methods as per given sample output.
#
# h. If there is NONE returned from any method print-No Data Found.
#
# Don't use any static text or formatting for printing the result. Just invoke the method and print the result.
#
# Sequence for specific object will follow same attribute sequence as mentioned in the question.You may refer to the sample Input/output for the display format.
#
# Sample 1 Input:<br>
# 5 <br>
# apnzhfi <br>
# 4 <br>
# 355<br>
# rznxxtj <br>
# iltluaz<br>
# 21<br>
# 346<br>
# jotbqoy<br>
# nhtshyg<br>
# 65<br>
# 226<br>
# fdkpcho<br>
# maybemo<br>
# 51<br>
# 380<br>
# rxplnwq<br>
# vzdegeg<br>
# 23<br>
# 126<br>
# lxbzypy<br>
# apnzhfi<br>
# Sample 1 Output:<br>
#
# apnzhfi<br>
# 4<br>
# 355<br>
# rznxxtj<br>
# nhtshyg<br>
# 65<Br>
# 226
# fdkpcho
